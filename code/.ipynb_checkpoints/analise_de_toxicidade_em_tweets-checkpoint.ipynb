# %% [markdown]
# # Análise de toxicidade em tweets sobre SARS-Cov-2

# %% [markdown]
# # Parte 1 - Coleta de dados

# %% [markdown]
# Importando as bibliotecas necessárias:

# %%
from googleapiclient import discovery
import json
import csv
import time
import pandas as pd
import matplotlib.pyplot as plt

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %% [markdown]
# Lendo os dados coletados atráves da plataforma Twitter Developer e PostMan:

# %%
df = pd.read_csv('covid-tweets.csv')

# %%
df
# Out:
#                           id  \
# 0      1,36777689921745E+018
# 1      1,36777689234709E+018
# 2      1,36777688061569E+018
# 3      1,36777687983975E+018
# 4      1,36777687942032E+018
# ...                      ...
# 19849  1,36764349932413E+018
# 19850  1,36764349925701E+018
# 19851   1,3676434990138E+018
# 19852  1,36764349797356E+018
# 19853  1,36764349794841E+018
#
#                                                     text Unnamed: 2  \
# 0      Jair Bolsonaro: \n“Onde tiver vacina para comp...        NaN
# 1      @Rconstantino Bordel é o Palácio do Planalto!!...        NaN
# 2      @ildeubasilio @Crikasetembro @elizia_leite @Ef...        NaN
# 3      @jairbolsonaro COMPRA AS VACINAS BOLSONARO?\nC...        NaN
# 4      Presidente do Senado diz esperar que ministéri...        NaN
# ...                                                  ...        ...
# 19849                       o joao teve covid SÓ UMA VEZ        NaN
# 19850  minhas n95 da 3m chegaram e agora eu vou poder...        NaN
# 19851  Vei, eu tô tentando ao máximo cuidar da saúde ...        NaN
# 19852  o mundo inteiro planejando um surubão pós covi...        NaN
# 19853  Fugi o ano inteiro do covid e cá estou eu ao l...        NaN
#
#       Unnamed: 3  Unnamed: 4 Unnamed: 5
# 0            NaN         NaN        NaN
# 1            NaN         NaN        NaN
# 2            NaN         NaN        NaN
# 3            NaN         NaN        NaN
# 4            NaN         NaN        NaN
# ...          ...         ...        ...
# 19849        NaN         NaN        NaN
# 19850        NaN         NaN        NaN
# 19851        NaN         NaN        NaN
# 19852        NaN         NaN        NaN
# 19853        NaN         NaN        NaN
#
# [19854 rows x 6 columns]

# %% [markdown]
# Deletando as colunas que não serão necessárias para a análise:

# %%
del df['id']
del df['Unnamed: 2']
del df['Unnamed: 3']
del df['Unnamed: 4']
del df['Unnamed: 5']

# %%
df
# Out:
#                                                     text
# 0      Jair Bolsonaro: \n“Onde tiver vacina para comp...
# 1      @Rconstantino Bordel é o Palácio do Planalto!!...
# 2      @ildeubasilio @Crikasetembro @elizia_leite @Ef...
# 3      @jairbolsonaro COMPRA AS VACINAS BOLSONARO?\nC...
# 4      Presidente do Senado diz esperar que ministéri...
# ...                                                  ...
# 19849                       o joao teve covid SÓ UMA VEZ
# 19850  minhas n95 da 3m chegaram e agora eu vou poder...
# 19851  Vei, eu tô tentando ao máximo cuidar da saúde ...
# 19852  o mundo inteiro planejando um surubão pós covi...
# 19853  Fugi o ano inteiro do covid e cá estou eu ao l...
#
# [19854 rows x 1 columns]

# %% [markdown]
# Limpando os Tweets para que não tenha caracteres especiais:

# %%
import re                                  # library for regular expression operations
import string                              # for string operations

from nltk.corpus import stopwords          # module for stop words that come with NLTK
from nltk.stem import PorterStemmer        # module for stemming
from nltk.tokenize import regexp_tokenize   # module for tokenizing strings
from nltk.tokenize import TreebankWordTokenizer

def clean_text(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
df['text'] = df['text'].apply(lambda x: clean_text(x))

# %%
df['text'].head()
# Out:
# 0    jair bolsonaro n“onde tiver vacina para compra...
# 1    rconstantino bordel é o palácio do planaltone ...
# 2    ildeubasilio crikasetembro elizialeite  tbm fi...
# 3    jairbolsonaro compra as vacinas bolsonaroncadê...
# 4    presidente do senado diz esperar que ministéri...
# Name: text, dtype: object

# %% [markdown]
# Removendo as "StopWords" para ter apenas as palavras chaves

# %%
def remove_stopwords(df):
    
    words = [word for word in text if word not in stopwords.words('portuguese')]
    return words

# %%
df
# Out:
#                                                     text
# 0      jair bolsonaro n“onde tiver vacina para compra...
# 1      rconstantino bordel é o palácio do planaltone ...
# 2      ildeubasilio crikasetembro elizialeite  tbm fi...
# 3      jairbolsonaro compra as vacinas bolsonaroncadê...
# 4      presidente do senado diz esperar que ministéri...
# ...                                                  ...
# 19849                       o joao teve covid só uma vez
# 19850  minhas  da  chegaram e agora eu vou poder ir a...
# 19851  vei eu tô tentando ao máximo cuidar da saúde m...
# 19852  o mundo inteiro planejando um surubão pós covi...
# 19853  fugi o ano inteiro do covid e cá estou eu ao l...
#
# [19854 rows x 1 columns]

# %% [markdown]
# Fazendo um WordCloud dos tweets obtidos:

# %%
tweets = df.dropna(subset=['text'], axis=0)['text']
# concatenar as palavras
all_tweets = " ".join(s for s in tweets)
 
# lista de stopword
stopwords = set(STOPWORDS)
stopwords.update(["da", "meu", "em", "você", "de", "ao", "os", "para", "pra", "um", "uma", "ou", "como", "nem",
                 "que", "se"])
 
# gerar uma wordcloud
wordcloud = WordCloud(stopwords=stopwords,
                      background_color="white",
                      width=1600, height=800).generate(all_tweets)
 
# mostrar a imagem final
fig, ax = plt.subplots(figsize=(10,6))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()
 
plt.imshow(wordcloud);
wordcloud.to_file("tweets_wordcloud.png")

# %% [markdown]
# Convertendo o DataFrame para arquivo json:

# %%
text = df.to_json('tweets.json')
# Out:
# <class 'NoneType'>

# %%
text = pd.read_json('tweets.json')
text
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Abrindo o arquivo:

# %%
with open('tweets_para_analise.json', 'r') as f:
        data = json.loads(f.read())
data
# Out:
# ['jair bolsonaro n“onde tiver vacina para comprar nós vamos comprar eu não estou negando o vírus muito pelo contrário estou dizendo que temos que enfrentar os problemas se todo mundo ficar em casa vai morrer todo mundo de fome”',
#  'rconstantino bordel é o palácio do planaltone a dona do puteiro está dando chilique ncadê as vacinas seu merdanahhh vc já se vacinou e fica aí recebendo verba pública da secom pra falar merda',
#  'ildeubasilio crikasetembro elizialeite  tbm fiquei nessa dúvida a cardiologista do meu pai me orientou “a vacina pode dar reação sim e é opcional se ele pegar o vírus o sofrimento será muito maior”naí decidi vacinar ele com  anos e não teve nenhuma reação com astrazeneca',
#  'jairbolsonaro itamaratygovbr ernestofaraujo compra as vacinas bolsonaroncadê as vacinas bolsonarononde está as vacinas bolsonaronvacine a população bolsonaronsão mais de mil mortos por dia sem vacinas bolsonaronvacina vacina vacina vacina e nqueremos vacinas bolsonaronninguém aguenta esperar as vacinas bolsonaro',
#  'não tem vacinas porque negou  milhões de doses da pfizer em julho de',
#  'lettsilv  joaquinteixeira vacina é imunizante não tratamento precoce qual o problema em em usar todas as cartas da manga se existe a possibilidade use a',
#  'e a história se repeti s em pleno século xxi   pandemia',
#  'se depender desse pessoal só  pode tomar a vacina chinesa só  essa que salva as outras não',
#  'machinemaah estranho pq diversos conhecidos meus que pegaram covid os cara receitaram',
#  'bempensativo monark vai lá tirar foto então e tem que ser do hospital nome incluso todo pois a ala de pacientes de  é por norma isolada do resto do hospital e nem todo hospital tem estrutura para receber doentes ou tem restrição quanto à sua especialidade',
#  'não consigo mensurar em palavras a felicidade que eu tô sentindo por saber que sábado meu vôzinho vai tomar vacina e muito em breve minha vó também amo',
#  'meu avô foi oficialmente vacinado contra a  ❤️',
#  'jairbolsonaro compra as vacinas bolsonaroncadê as vacinas bolsonarononde está as vacinas bolsonaronvacine a população bolsonaronsão mais de mil mortos por dia sem vacinas bolsonaronvacina vacina vacina vacina e nqueremos vacinas bolsonaronninguém aguenta esperar as vacinas bolsonaro',
#  'patrycyamg claudioedantas pois é ivermectina não cura covid assim como dipirona e demais remédios pgripe não  cura gripe  boa parte das doenças não tem um remédio como bala de prata mas sim medicamentos que auxiliam o paciente durante o processo de cura evitando o óbito',
#  'claudioedantas quem falou em cura diminui a carga viral se tomado precocementennvai na cura a covid deixa de ser trouxa rapaz',
#  'vacinação no brasilnbrasil deverá somar mais de  milhões de vacinas até o fim de abriln',
#  'bandjornalismo presidente do mimimi cadê a correção do imposto de renda cadê o combustível barato cadê as vacinas',
#  'do coronavirus quando perguntarem o que é massa de manobra basta utilizar essa informação como exemplo',
#  'andretrig queria ver se ele teria essas mesmas atitudes e falas se por acaso do destino algum membro da familícia dele perdesse a vida pra covid',
#  'jornaldacbn o apelo do prefeito de pirassununga faz sentido pq pelos dados da prefeitura a média de casos confirmados  em  foi de  e jan e fev  saltou p  de  e em  dias em março  p uma cidade de  habitantes',
#  'ludmilagrilo negacionismo é falar que vacina não funciona que da casa dele só o cachorro vai tomar vacina que a ciência não sabe o que diz ao não recomendar cloroquina isso é negacionismo não precisa de uma palavra não tem muito mais em palavras e vídeos que mostram',
#  'carmelonetobr jairbolsonaro atrasado como sempre se negou a comprar as vacinas no final no ano passado só agora depois de muitas mortes e pressão resolveu fazer o obvio e ainda tem gente que aplaude lamentável',
#  'se registra  novos casos de  e mais nove óbitos que estavam em investigaçãon',
#  'xelelete folhape kkkkkk o cara que conseguiu a vacina primeiro que todo mundo inclusive primeiro que o governo federalnnmesmo não alinhado às ideias de doria não tem como não reconhecer o golaço que ele feznnaliás tem basta ser cretino',
#  'sinceramente eu não confio nesses números tudo está sendo forjado para prejudicar o atual governo todos os óbitos no país tem como causa mortis suspeita do  o que não faz qualquer sentido nnbrasil tem mais  mortes de covid em um dia',
#  'parem de pegar covid vcs tao moiando meu baile',
#  'pq diabos o casal teve que fazer um exame em laboratório particular para ter o resultado correto o que esta havendo com os exames dos hospitais meu noivo quando teve covid tbm teve  falsos negativos',
#  'euclidescrf o problema aqui não é as vacinas e sim um sistema corrupto comandando um povo corruptível',
#  'elizialeite humbertoreisjr minha vizinha susan de  anos tomou a primeiro dose dessa vacina  dias depois advinha só morreu infelizmente acabou sendo atropelada por um ônibus e não resistiu',
#  'jairbolsonaro compra as vacinas bolsonaroncadê as vacinas bolsonarononde está as vacinas bolsonaronvacine a população bolsonaronsão mais de mil mortos por dia sem vacinas bolsonaronvacina vacina vacina vacina e nqueremos vacinas bolsonaronninguém aguenta esperar as vacinas bolsonaro',
#  'itacaré continua com vacinação contra o  na sede e em\xa0taboquinhas',
#  'rpsenador você só fala de vacina pelo amor de deus vacinação é impostante mas  trabalhar para cuidar da família  é de extrema importância eu repito trabalhar e não receber auxilo deixe um pouco a vacina de lado pois o min da saúde é competente ponha pra votar as pautas do gov federal',
#  'com tramp eua vive dias de caos em relação as mortes por  nncom biden nnentendedores vão entender',
#  'estadao o governo federal fechou contrato em agosto de  com oxford  astrazeneca a primeira vacina apresentada ao mundo foi após a eleição americana e só em dez  foi aprovada na inglaterra',
#  'claudioedantas deixa de falar merdatem ajudado simtomamos todostanto no trabalho como minha família só um pegou covide bem leve  procure divulgar o que salva vidadeixe de postar bobagem',
#  'jairbolsonaro vacina já presidente pare de ser teimoso e veja a situação vacina já',
#  'venha vacinas',
#  'é amigos chegou o fatídico dia em que venho comunicar que faleceu um parente meu por covid deixando  filhos inclusive uma criança de  anosnnespero que minha prima encontre forças para enfrentar tudo sozinha e que ele descanse em paznnse cuidem',
#  'o número dos novos casos de contágio da covid ontem nmaior que o dos estados unidos que continua em queda nmais uns  dias e vamos seguir ao pódio desta tragédia nveremos qual será o comentário do abominável neste dia ncoronavirus',
#  'paulocruzphi vamos fazer essa conta no brasil qual a população do  quantos óbitos por coronavírus nas pessoas menores de  anos qual a porcentagem qual a porcentagem de internação dos menores de  anoscuidado sim pânico não',
#  'sandrocezzar  vitorsergio cara tudo isso é hipocrisia vc acha que tem alguém preocupado com vidas se tivesse não teria metros e ônibus super lotados tudo isso é pra aparecer politicamente ficam tirando fotos com a vacina chinesa e aí quando a coisa aperta vem com esse papinho',
#  'carlosjordy esse é um covarde vai ficar bilionário com a covid mas vai morrer na praia',
#  'machinemaah mds em q mundo tu tá aq tem até kit covid e hj mesmo uns empresários vão abrir uma clínica apenas para dar cloroquina e o remédio pra verme pra em tem covid',
#  'meu irmão veio pra fila as  da manhã pra minha avó tentar a vacina ele vai perder a carteirinha de crente bolsominion por isso',
#  'sextouuu meus amg mas bora ficar em casa pq covid ta ai e pode te pegar se ele não pegar eu pego',
#  'para que não se esqueça daqui saíram os  bi aniquiladores',
#  'folha presidente do mimimi cadê a correção do imposto de renda cadê o combustível barato cadê as vacinas',
#  'verajazz oseparatista anapaulavolei invejosa a vacina mata sim segundo os dados do  governo britânico  está escrito nas bulas de todos medicamentos e vacinas tbém',
#  'efiemi jornaloglobo govbr descanse a sua vacina já está a caminho logo logo vc vai levar a sua picadinha',
#  'jornalnacional presidente do mimimi cadê a correção do imposto de renda cadê o combustível barato cadê as vacinas',
#  'se não existisse coronavírus eu estaria indo a pé pra escola conversando sobre a vida com o rachid e animado porque hoje tem educação física',
#  'caiofabiovvtv até tu caio exibindo trecho de vídeo sem contexto do fato ali discursado tenho certeza que você com a caneta presidencial na mão ainda não teria conseguido comprar mais vacinas que o governo federal atual',
#  'bolsonarovao chorar até quando será que a onu e as congeneres nao teem mao em governantes que estao a massacrar o proprio povo com as atitudes irresponsaveis e assassinas perante o flagelo da  estes individuos deviam ir parar a um tribunal internacional',
#  'andrezadelgado  tatinefertari será que não se materializaram porque foi o último país a se movimentar pra compra das vacinas será que não foi porque tentou até quando deu não reconhecer a coronavac criando uma briga política pela vacina',
#  'galodeluta estão produzindo a quinta vacina ✊',
#  'esse mês completa  ano dessa histeria coletiva sobre um vírus produzido pela china comunista não me iludo com os governadores e prefeitos muito menos com o atual colegiado do stf nnbrasil tem mais  mortes de covid em um dia',
#  'radiobandnewsfm presidente do mimimi cadê a correção do imposto de renda cadê o combustível barato cadê as vacinas',
#  'aí tu chega na firma e reencontra colegas afastados p covid rindo pq voltaram e s máscarasjá peguei tá dominado que vontade de dar um soco nas',
#  'descobri hj nos descontos do convênio que meu teste de covid custou  dinheiros',
#  'herbertipedroso teve outro caso dramático um bolsonarista seguia à risca os exemplos do presidente ignorando máscaras etc ao chegar em casa a esposa se trancava no quarto com duas filhas ela ameaçou ir para a casa da sogra ele não mudou ela saiu de casa dias depois ele morreu de covid',
#  'botafogo na liderança sério mas o time estavanah botafogo que vc diz é o bairronah a liderança é no ranking da menor taxa de isolamento social desde o início da pandemia de  merda heinn',
#  'kraftwidholzer normandico  tiago tonskatemore lindolfojunior mblivre jairbolsonaro então a vacina é como vinho quanto mais tempo melhor',
#  'na pandemia ainda tem torcida bolsonaro x moro vacinas e número de mortos detalhe',
#  'covid comendo no centro na bahia e os times de futebol pra cima e pra baixo com seus jogadores',
#  'só vendo as desgraças vindo da covid eu só tenho uma visão sobre isso tudo covid no brasil vai ser uma peste negra  muita gente vai morrer ainda e ninguém vai saber pq e ninguém se importa mais',
#  'os novos leitos serão distribuídos pelas três macrorregiões de saúde da paraíba contemplando municípios como joão pessoa campina grande cajazeiras patos pombal e piancó',
#  'caxineidy é eles só ligam para o bolso delesnão agregam soluções e não estão nem aí para a covid',
#  'cleitonjesuino monark mas quero saber quantas pessoas morreram por conta disso pq não existe só covid existe outras doenças e outros problemas',
#  'uma mulher falando sobre covid com meu painela tem que abrir tudo e cada um fazer sua partennela na rua sem máscara',
#  'bolsonaro “tomou” vacinas de juiz de fora e prefeita margarida negocia com astrazeneca e sputnik por  milhão de doses',
#  'covid ano  brasil em colapso nas mãos de um genocida e seus cúmplices  via youtube',
#  'pode não curar covid mas seu uso constante mata os vermesnpodemos deixar o gado tomar o remédio em grandes doses pode ser benéfico para a sociedade',
#  'urtlakbot izzynobre mas lockdown hoje é uma medida política justamente pq mostra a ineficiencia dos políticos em se preparar mesmo depois de um ano de pandemianne realmente lockdown não funcionou em alguns lugaresnargentina está aí pra provar isso nnlockdown não é curavacina é',
#  'viniciuspoit porque não permitem que as clínicas de vacinas comprem doem a metade e vendam a outra metade',
#  'botsentinel presidente do mimimi cadê a correção do imposto de renda cadê o combustível barato cadê as vacinas',
#  'vereador pede fiscalização no cumprimento das medidas contra',
#  'pernambuco registra pior semana do ano podendo adotar medidas mais rígidasn',
#  'lhmandetta se não havia como ter certeza que era covid o que se pensava naquele momento foi feito porém tudo muda a partir da evolução do problema o que não mudou foi o comportamento dos negacionistas induzindo o povo à morte',
#  'cadê a vacina máscara e distanciamento social respeito ao povo brasileiro',
#  'vichtt mano a desinformação é gigantescaaaanpior que não é difícil ter acesso à informação da composição das vacinas pelo menos não pra uma pessoa como ele que com certeza tem um celular a disposição',
#  'toque de recolher óbvio e light medida que nem inglês quer ver e acreditar continuaremos a contribuir com a assombrosa estatística de mortes por  equivalente a quedas de mais do que  boeings  lotados por dia ☠️✈️☠️✈️☠️✈️',
#  'a fundação oswaldo cruz fiocruz divulgou nesta quintafeira  que há no paraná\xa0e em várias regiões do país\xa0variantes do novo coronavírus em plena circulação no estado segundo o estudo   amostras de rtpcr com grande carga viral enviadasnn',
#  'engraçado como tem especialista espalhados por toda parte e as autoridades permanecem aturdidas perante o vírus e sua excepcionalidade nprecisamos de vacinapressionemos nessa direçãodepois se discute o restoe psaber q vacina é caminhonem precisa de especialização',
#  'as autoridades sanitárias da irlanda estão a investigar quatro acontecimentos de natimortos que podem estar associados a um surto de  anunciou na quintafeira o diretorgeral do departamento da saúde ronan glynnnnotician',
#  'mothersmilkhoe uma desgraçada filha de uma puta que faz isso com pobre do bichinhonuma peste dessa depois morre com um câncer covid ou etcdepois fica teclando porque tá sofrendo',
#  'custo do mito é  matar mais que o vírus  vacina é o impeachment urgente',
#  'se a eficácia da cloroquina não fosse apenas um mito quanto recurso esta fábrica poderia receber do bndes   marketing bolsonaro fez de graçancoronavirus impeachmentja forabolsonaro',
#  'uoleconomia presidente do mimimi cadê a correção do imposto de renda cadê o combustível barato cadê as vacinas',
#  'além paraíba registra  novos casos da  e mais um óbito o',
#  'carlosbolsonaro e continuamos a dizer economia está uma bosta porque seu pai é negacionista e morrem quase  mil pessoas todos os diasnnse tivéssemos iniciado a vacina antes associado a um lockdown decente nossa situação estaria muito melhornnimpeachmentbolsonarourgente',
#  'subtenenteedgar nem precisa perguntar o obvio o que é uma vacina é o virus  atenuado dizem  que vão introduzir no teu corpo na esperança de que teus anticorpos sejam fortes para combater o virus e criar uma memoria  para que toda vez que for atacado pelo virus seus anticorpos reajam',
#  'eu n acho q tô com covid pq meu nariz tá entupido e tô com dor de ouvido q são coisas q sempre tenho qnd chove e faz frio pego gripe e fico assim',
#  'sabe por que a mídia não se fala mais de covid nós estados unidosnnporque lá a esquerda ganhounnenquanto eles não derrubarem a direita aqui no brasil não vão parar nnbasta você ter esse entendimento',
#  'estadao variante é o novo nome pra dizer que a vacina não funciona',
#  'março de  bolsonaro fazendo porra nenhuma pra combater a pandemia mais de  mil mortes pelo covid e a sarah ainda tem coragem de dizer que não quer impeachment do verme pq gosta dele não é mais questão de política é caráter e humanidaden',
#  'situação economica de angola face a metamorfose da  em   via notícias de angola',
#  'ontem eu conversando com amiga minha ela teve a cara de pau de dizer que morre gente todo dia tipo normalizem a morte por covid quero ver se fosse algum ente querido dela morrendo sem leito em hospital o ser humano é podre mesmo deu até vontade de me afastar',
#  'jairbolsonaro mesmo que pra isso ele morra de covid pq a o presidente do seu país é um inútil incompetente que perde o timing de garantir vacinas a sua nação nnagora se fosse para abrir a boca para falar burrices esse mesmo presidente seria o primeiro do mundo',
#  'stehpapaiano a doença que dá holofote no indicador e polegar é a covid',
#  'jairbolsonaro stehpapaiano presidentenem essas vacinas tem contra indicaçãoporque nao fazem teste nas pessoas pra ver se tem covid ou nao antes de vacinarela é pra prevenir e nao curarestao querendo dinheiro pra campanha politica ano que vemé armação',
#  'kaaadonato não acredito ka  melhorasnmeu avô está mal foi internado ontem devido à covid não sei nem o que pensarsó espero que todo esse pesadelo acabe',
#  'com a barriga vazia não se pensa o que deveria ser feito é pressão no gov federal pra aquisição de vacinas mas como pedir razão de uma população desesperada por sustento caos total',
#  'só pega covid se ficar no bar e restaurantes mas dentro do  lotado ate o cool fazer bico não né entendi esse decreto aí',
#  'iaragb e depois se acontecerem obitos e complicacoes de todas estas vacinas experimentais e feitas a toque de caixa algumas nem bem testadas em idosos a culpa já sabemos no colo de quem vão jogar',
#  'fabianapizzo  janainadobrasil o governo não comprou vacinas em dez foi por conta os países detentores da fabricação estarem na frente óbvio agora segundo revista exame a ue está tendo dificuldade em obter é  pandemia a demanda está sendo maior q a produção por isso que tratamento precose ajuda a cuidar',
#  'morte com covid após tiro é parte das estatísticasnhá métodonnão se justifica essa cepa e esse novo piconnega•sion•irisnna veia e na fénestamos na fase da negação',
#  'damadeferroofic lucianohuck vamos traduzir para o gado pq ela não consegue entender nestamos vacinando em ritmo bem lento pq o excelentíssimo senhor coronel bozonaro ao invés de correr atrás de vacinas ficou de piadinha escrota e incentivando ema a tomar cloroquina',
#  'tem gente já tomando a ° dose dessa vacina e eu nem tomei a primeira ainda',
#  'cayrote deboraddiniz mais uma criança que perde a mãe para o covid',
#  'geocaio pegar covid ser corno  vez uma vez',
#  'ferncastillov alecollive climainfonews ideias distorcidas e mentirosas é  mentira que tivemos mais de  mil mortes de covid e o presidente se negou a comprar  milhões de doses de pfizer e comprou cloroquina tb é mentira que ela foi atrás de um spray q não passou da fase',
#  'a média móvel de óbitos por coronavírus no brasil ficou em  nesta quintafeira  o maior patamar já registrado em toda a pandemia o globo',
#  'eu deixava morrermenos um pra tomar a vacina',
#  'jairbolsonaro essencial é vacina',
#  'fiocruz alerta para circulação da nova variante da  no\xa0pr',
#  'cadê a vacina máscaras e distanciamento social',
#  'a pessoa fez exame de covid que não saiu resultado e ta postando fotos trabalhando e zanzando em fpolis e olha a pessoa nojo',
#  'janainadobrasil sr jairbolsonaro fez tudo o que pode  sr jdoriajr errou em tudo  onde estão os equipamentos comprados  os hospitais de campanha ficaram vazios ontem fui a um posto de vacinação e estavam com muito pouco movimento  a mídia exagera muito atenção para não sobrar vacina',
#  'eu sempre avisei aqui e em todas as outras mídias não tomem essa vacina até porquê o dr wong avisou que todas eram suspeitas',
#  'uma professora na minha escola faleceu de covid meu deus quando isso vai acabar',
#  'brasil confirma  casos de reinfecção saiba como isso redefine pandemia  via',
#  'pelo menos  mil profissionaisdesaúde morreram de  em  em todo o mundo avançou hoje a amnesty apelando a uma “ação urgente” para acelerar a vacinação destes trabalhadores “altamente expostos” e várias vezes “desprotegidos”nnotician',
#  'portuguesdoluan comecei a ver várias notícias sobre o covid e fiquei mal mas ja to melhor',
#  'zehdeabreu e que chama as pessoas de idiotas por quererem vacina',
#  'novaeramidia se vc leva uma topada na calçada já é covid',
#  'filipecampante pregadores do caos vamos fazer essa conta no país todo qual a população do brasil quantos óbitos por coronavírus nas pessoas menores de  anosqual a porcentagem qual a porcentagem de internação dos menores de  anosparem de disseminar pânico cuidado sim mas sem pânico',
#  'presidente bolsonaro fala sobre crédito para compra de vacinas',
#  'mellziland potencial vacina contra câncer em desenvolvimento nos eua',
#  'coronavírusneuropa e eua têm mais mortes por habitantes que o brasil em razão do',
#  'andrefran povo ainda está no conto da farsa a jato e apoiando o neoliberalismo por causa dos noticiários de rádio e tvncovid é por festas depois das  e aulas protege criançasnpreço do combustível é por conta do valor internacionalnnada na economia é culpa do governo',
#  'oms  incentiva as pessoas a jogar durante o surto de coronavírus nnmuitos meses atrás a organização mundial',
#  'cdslitoral sul discute propostas paraa compra de vacinas contra o',
#  'não entendi cadê a ciência aplicada querendo isolar o órgão regulador do país e colocar no stf eles são especialista em saúde pública todos querem vacina confiável e menas política em uma situação difícil dessa',
#  'desisti da anvisa e decidi acreditar no stf afirma rui sobre ação para aplicação da vacina russa  via bocaonews',
#  'que vacinar professores que nadanprimeiro porque as aulas não vão voltar segundo porque assim que alguém deixar abrir eles vão engatar uma grevenvacina os motoboys então esses eu tenho certeza que iria afetar todo mundo se fossem parar',
#  'idosa não aceita ser vacinada por enfermeiro negro em são paulonncaso de racismo ocorreu na cidade de taquaritinga e gerou revolta de funcionários e testemunhasn',
#  'é isso aí solnorabonimpossibilite desses governadores e prefeitos comunistas de comprarem insumos para vacina a previdência e a economia do país agradecem precisamos de mais mortes seu eleitorado fiel te defenderá até a morte não importe o que você faça',
#  'bdsp difícil a situação ou gasta muito para se proteger no carro ou paga menos para andar no transporte público com aglomeração e um risco maior de contaminação do coronavirus',
#  'borabrasil joeldatenareal vc é um cara do bem chama a dra raissa e o dr cássio de porto feliz eles têm provas robustas de cura essa curva despenca com eles ajuda o povo cara não seja  negacionista da cura vc é seu pai podem salvar vidas chama eles vacina demora',
#  'rodrigomaia seu mentiroso o nosso pr já mostrou que ela não foi vacinada com essa vacina deixe de mentir',
#  'senoriovisto o problema não está só na covid que é mal conduzida  né geral o deboche do presidente com o brasil em todas as esferas',
#  'vacinação contra a  começa hoje em sines',
#  'curitiba registrou nesta quintafeira   novos casos de  e  óbitos de moradores da cidade infectados pelo novo coronavírus conforme boletim da secretaria municipal da saúde',
#  'idosa morre por  em sc e filhas permanecem entubadas o que nos resta é rezar diz família  santa catarina',
#  'brunocostadj edsonhcs monark faça o oposto do que você colocou na última sentença então sob a promessa de colocar eu errei gravado na porta da enfermariautilápide caso você vá fazer companhia aos pacientes de  npaga para ver ou você só quer que os outros paguem por você',
#  'tá de brincadeira o preço dos combustíveis sem vacina “frescura e mimimi” e eles estão protestando contra as medidas de restrição não posso crer nisso',
#  'senoriovisto o país não aguenta e  nem merece é senador frouxo contraia covid e  continue pensando a mesma coisa  senador',
#  'circulação entre concelhos proibida a partir das',
#  'claramente temos que isolar o jairbolsonaro pois a variante de covid que ele pegou matou o único neurônio que tinha presidenteacefalo',
#  'rosana quem é maldito   o governador  o governo de são paulo tem que acordar e perceber que o covid chegou e fazer alguma coisa para resolver nao faz nada fechar a cidade qualquer um faz quero ver é mostrar o  bilhões que recebeu a  ano atrás para aplicar no covid e nada',
#  'santos antecipa segunda dose da vacina para rapaziada acima de  anos',
#  'anac abre procedimento para apurar batida de avião com vacinas da  em jumentos na bahia',
#  'ah mas sabíamos que a sarah votou  o gil perguntou se houvesse um impeachment iriam avisálos e a sarah disse que não mas ele retrucou dizendo que avisaram sobre a covid e ela finalizou dizendo que covid era coisa ruim e eles não dariam notícia boa',
#  'trompetista zehdeabreu  dia  foi meu irmão mais uma vitima do desgoverno se tivesse comprado a vacina que chegaria em dezembro ele estaria imunizado mas usou  para viajar e comprar cloroquina  invermectina leite condensado e mansão por aqui estamos desesperados de dor',
#  'estou com mt medo da minha mãe estar com covid',
#  'vai comprar vacina na casa da sua mãe  palavras de um presidente que chama  mil mortes de frescura e mimimi o que falta para tirarem aquele homem lá será que o povo está tão cego querem culpar prefeitos e governanadores só quem está sofrendo pode sentir a dor',
#  'dedefla carmilatirenato eu tenho doença auto imune e quando tenho qq sintoma diferente faço o tratamento precoce além disso tomo ivermectina de  em  dias um dia tomo zinco diariamente e vitamina d b c não tenho o menor cuidado e semana passada tive contato com uma amiga cujo filho teve covid',
#  'jairbolsonaro cadê as vacinas bolsonaro',
#  'oantagonista jairbolsonaro ei em vez de esbravejar será  que v não libera o marionete do pazuelo para comprar mais vacinas para os brasileiros',
#  'senadorcidgomes vergonha  foi o que fizeram com os bilhões em verbas que receberam para combater covid  o resto é resto onde estão os leitos e os hospitais para o  povo ser atendido',
#  'vacinação contra a  brasil já usou  milhões de doses  via',
#  'entendi é mt importante eles se vacinar em até pq quando eu for prai tem o risco de eu pegar covid no aereoporto',
#  'hscrfs sem noção toda aí tu ou ela pega covid e já era',
#  'sera se peguei covid de novo',
#  'minto vai comprar vacina na casa da sua mãennuhuuuu mito mito mito deus é contigo vc é enviado de deus mito mitonnesse é o brasil',
#  'número de investidores na bolsa cresce  e lucro líquido da empresa tem alta de  em  butantan recebe insumos para produzir de  milhões de vacinas  com aprovação da pec emergencial bolsa fechou com alta de  dia',
#  'cadê a vacina',
#  'wanezzia provavelmente todos furaram fila da vacina',
#  'tatinefertari deus disse q ñ demos pérolas aos porcos mas vamos fazer uma exceçãontatinefertari ñ sei se a tua capacidade chega o suficiente p ler em espanhol pq gente como vc gosta de lacrar mas ñ sabe fazer a letra o com um canudonnotícia hoje da españanfaltam vacinaseh bolsonaroo',
# ...
#  'a solução é botar um atrás do outro que nem gado mesmo e sair aplicando vacina mas os políticos daqui são os fazendeiros que apenas “ferram” seu gado e não vacinam seu gado',
#  'estudiocbn eu não vi minha mãe depois que ela morreu nem num saco vi um caixão todo enrolado em silver tape ela entrou por uma porta e pra mim ela nunca saiu ela não morreu de covid',
#  'hoje tem formatura é ninguém pode vir por conta do covid mo parada',
#  'já se sabe um pouco mais há aqui ilegalidade qb para um inquérito judicial nn',
#  'minha mãe disse q n vai deixar eu ir pra escola pq os casos de covid ta aumentando muito mds vou reprovar',
#  'estadao o ministério só vai comprar porque identificou que as vacinas podem ser usadas como instrumento de chantagem aos estados e municípios e com finalidades eleitoreiras',
#  'o ideal e acabar com a raça de um filha da puta desses trancando ele numa ala hospitalar de covid e torcer pelo vírus',
#  'cnnbrasil vacina não se compra na esquina da uma olhada o que está acontecendo na frança e portugalc uma população reduzida',
#  'eai covid vai embora quando',
#  'gladbrasileiro andersonleony capitaowagner entender obviedades não se trata nem de inteligência  perceber que tem gente morrendo ainda que cloroquina não  funcionou nem no brasil nem em lugar nenhum do mundo e entender que vacina distanciamento máscara e higiene qualquer idiota consegue fé',
#  'na gasolina mas não vai comprar vacina \u200d♂️',
#  'bolsonaro critica frescura no combate à',
#  'rafaelsatie kelnereduardo pauloeneas sério isso enquete na de ontem a maioria acha que o responsável pelo avanço do covid no brasil é o presidente e agora como fica a enquete descarta',
#  'laurinhaironic realmente começaram a aparecer muito mais pessoas com covid do que antes da aplicação isso que acontece quando querem uma vacina as pressas estão usando os brasileiros como cobaia  impeachmentdeagripinodoriaja',
#  'não duvidemos se a covid  lhe fará justiça seria justo que provasse do próprio venenonbolsonarogenocida',
#  'guanambi e cidades da região sudoeste da ba terão restrições de atividades a partir de\xa0sextafeira',
#  'leilagermano startupdareal só estão demorando demais com a vacina fora as que foram pro lixo',
#  'técnico alberto félix e mais dois jogadores testam positivo para coronavírus e desfalcam rioclaro nnfonte geglobo nn',
#  'sugestão anotar o nome de todos e caso precisem de hospital por covid mandar pro fim da fila',
#  'não gostei da entrada do echaporã rende mais pela esquerda uma pena o guilherme com covid',
#  'estadao prontificounmorreu enquanto morre morrerão  brasileiros sem vacinas sem assistência sem a ciência ncustobolsonaro nbolsonarocoveirodobrasil nna casa da minha mãe não tem vacinas teve um corpo que não foi vacinado',
#  'jairbolsonaro e a vacina',
#  'de fila  é muita gente julgou a vacina falava mal da china',
#  'olavoopressor continui fumando assim feito chaminé cigarro faz bem pra saúde como o senhor ensina o que faz bem pra saúde é vacina que o senhor ensina ser perigo é ou não é',
#  'acontece entenda por que higiene bucal é ainda mais importante em tempos de',
#  'claudioedantas saiba mais em\xa0\xa0\xa0agora rn',
#  'somos guerreiras e guerreiros que precisamos estar preparados para a guerra contra a  exigimos vacina',
#  'engraçado  né nos caras querem fazer lockdownnpor causa  do covid falando que tem bastante pessoas  ruas nmais  esquecem dos trabalhadores que estão na rua pra leva alguma coisa pra casa pra sua família na passa necessidades',
#  'vempraruabr qual o posicionamento de vcs quanto aos erros seguidos dos governadores já pressionaram para eles mostrarem o que foi feito com o dinheiro enviado é só o brasil que não tem a quantidade necessária de vacinas',
#  'variantes mais preocupantes já prevalecem em pelo menos seis estados diz fiocruz     itatiaia',
#  'jornaloglobo de hoje pária global da pandemia brasil vira ‘ameaça sanitária’ no mundo especialistas economistas e governos acompanham c perplexidade a condução da crise no país e o avanço de novas variantes do novo coronavírus',
#  'covid é real',
#  'acontece entenda por que higiene bucal é ainda mais importante em tempos de',
#  'não desejo ansiedade para ninguém ontem estava com uma tosse e coloquei na cabeça que havia pego covid fui olhar o sintomas como boa hipocondríaca que sou passei a noite acordada sentindo todos os sintomas de um quadro leve',
#  'governo já garantiu  milhões de doses de vacinas contra',
#  'acontece entenda por que higiene bucal é ainda mais importante em tempos de',
#  'doze cidades têm alto risco de contaminação para a  e  risco moderado',
#  'uol gostam tanto comparar com o que se passa lá fora e agora  quando média vacinas melhor que europa  também é culpa do bolsonaro',
#  'visitas para jovens infratores que estão em centros da funase são suspensas por causa da alta da covid',
#  'acontece entenda por que higiene bucal é ainda mais importante em tempos de',
#  'livro branco da pandemia faltaram dados para gerir a  em portugal by observadorpt',
#  'eua com  mortos e  novos casos  rtp notícias',
#  'acontece entenda por que higiene bucal é ainda mais importante em tempos de',
#  'bom dia começando o dia com a seguinte pergunta o vagabundo vai cumprir a sua obrigação constitucional de comprar vacinas para todos os brasileiros quando',
#  'ontem conheci uma irmã e outro primo ansiosa pra vêlos pessoalmente covid fdp',
#  'graças a deus é sextaaa conseguimo cambada foi uma semana difícil mas chegamos bom final de semana pra todos cuidem com o covid por favor e se puder fiquem em casa❤☀️',
#  'recebi no whatsapp msg fake sobre covid e vacinas  é surreal quem mandou foi o marceneiro q fez uns trabalhos aqui  só consegui perguntar como consegue acreditar em tanta mentira e se ele sabe que pode ser responsabilizado por divulgar informações',
#  'vaidesmaiar falou que tomou ivermectina preventivamente pra covid no começo do programa tava na cara né gente',
#  'chega de frescura de mimimi vão ficar chorando até quando diz bolsonaro sobre pandemia monstro o único projeto de governo que conhecemos é de destruir o país presidente genocida impeachment',
#  'acordando cedo hoje pra ver a véia tomar vacina',
#  'como eh bom morar num país q levou a pandemia a sério e hj já não tem nenhum caso de covid',
#  'jairbolsonaro hoje o waldemir da padaria estava muito abatido porque perdeu um primo ontem pra covid eu cheguei perto pra consolar e faleinnchega de frescura e mimimi vai chorar até quandonnele me deu um soco no nariz e me expulsou de lá  que eu falei algo errado',
#  'juiz autoriza que motoristas de uber de brasília importem vacinas contra a covid',
#  'dombaruque genheleno bonoropistol passou sim e  pra variar jairbolsonaro  falou m como sempre sobre as vacinas né uma coisa q acho estranho se ele quer o povo trabalhando porque não vacina em massa o povo',
#  'monteirounai marcelofreixo se o governo federal quisesse mesmo comprar acha que estaria essa novela os estados entraram na justiça justamente pq o presidente falou infinitas vezes que não compravanão tinha pressanão confiavanão queria vacinas ele só faz algo quando o doria se mexe',
#  'bdsp fase vermelha escolas abertas casos de covid aumentando nas escolas não tem sentido',
#  'andrecouniverse triste pensar que até lá a gente ainda pode nem estar vacinado e lutando contra picos de covid ainda sabe cinema um sonho distante pra gente migo eu só quero chorar',
#  'santa catarina entra em restrições com mais  mortes e sem um único leito de uti nem\xa0vacinas',
#  'risco deles morrerem por covidnne outra comparar ir numa festa de aniversário com sair de casa pra compra miçanga pra trabalhar com isso e arrecadar dinheiro pra faculdade foi maduro tu eh madura mesmo ou se eh uma pirralha que acha que eh madura so pq namora e trabalha',
#  'fato sem vacina não tem economia',
#  'o brasil certamente será o único país que não vai conseguir se livrar do coronavírus e nós vamos ficar com inveja do resto do mundo vivendo novamente e nós presos pelo corona mas isso não é culpa só dos políticos cada um tem um pouco de culpa nisso tudo',
#  'pontaozaooo  ja tava p surgir um ano antes do covid aparecer',
#  'piauí tem  mortes nos primeiros quatro dias de\xa0março',
#  'boma mídia funerária já está praticamente afirmando que todos estão com covid ou já pegaram covid vacina já foram aplicadas aos milhõesserá que nos próximos dias o covid será exterminado pelo q vejo na mídia todos já pegamosou continuarão dizendo que estamos com ele',
#  'slysalmon vaidesmaiar nao foi isso foi sobre a vacina o contexto do impeachment foi a lumena q disse depois',
#  'astridfontenell é filho da a mãe dele tomou a vacina e foi a coronavac',
#  'janainadobrasil ok mas a vacina mal deu pra vacinar os profissionais da saúde por favor jana',
#  ...]

# %% [markdown]
# # Parte 2 - Análise de tweets com Perspective API

# %% [markdown]
# Importando a chave para o uso da Perspective API atráves do GoogleCloud

# %%
API_KEY = 'AIzaSyB_wryWmzpPOdmlt_j6bmnXrg_0xBFVUBY'

# %% [markdown]
# Realizando a análise de tweets com a Perspective API:

# %%
client = discovery.build(
  "commentanalyzer",
  "v1alpha1",
  developerKey=API_KEY,
  discoveryServiceUrl="https://commentanalyzer.googleapis.com/$discovery/rest?version=v1alpha1",
  
)

analyze_request = {
    'comment': { 'text': f'{line}' },
    "requestedAttributes" :{'TOXICITY': {}},
    
}


for line in data:
    analyze_request.get(line)
    print(line)
    time.sleep(2)
                
    response = client.comments().analyze(body=analyze_request).execute()
    print(json.dumps(response, indent=2))

with open('perspective-response.json', 'w') as f:
    json.dump(response, f)
# Out:
# jair bolsonaro n“onde tiver vacina para comprar nós vamos comprar eu não estou negando o vírus muito pelo contrário estou dizendo que temos que enfrentar os problemas se todo mundo ficar em casa vai morrer todo mundo de fome”
# {
#   "attributeScores": {
#     "TOXICITY": {
#       "spanScores": [
#         {
#           "begin": 0,
#           "end": 100,
#           "score": {
#             "value": 0.11257359,
#             "type": "PROBABILITY"
#           }
#         }
#       ],
#       "summaryScore": {
#         "value": 0.11257359,
#         "type": "PROBABILITY"
#       }
#     }
#   },
#   "languages": [
#     "pt"
#   ],
#   "detectedLanguages": [
#     "pt"
#   ]
# }
# rconstantino bordel é o palácio do planaltone a dona do puteiro está dando chilique ncadê as vacinas seu merdanahhh vc já se vacinou e fica aí recebendo verba pública da secom pra falar merda
# {
#   "attributeScores": {
#     "TOXICITY": {
#       "spanScores": [
#         {
#           "begin": 0,
#           "end": 100,
#           "score": {
#             "value": 0.11257359,
#             "type": "PROBABILITY"
#           }
#         }
#       ],
#       "summaryScore": {
#         "value": 0.11257359,
#         "type": "PROBABILITY"
#       }
#     }
#   },
#   "languages": [
#     "pt"
#   ],
#   "detectedLanguages": [
#     "pt"
#   ]
# }
# ildeubasilio crikasetembro elizialeite  tbm fiquei nessa dúvida a cardiologista do meu pai me orientou “a vacina pode dar reação sim e é opcional se ele pegar o vírus o sofrimento será muito maior”naí decidi vacinar ele com  anos e não teve nenhuma reação com astrazeneca
# {
#   "attributeScores": {
#     "TOXICITY": {
#       "spanScores": [
#         {
#           "begin": 0,
#           "end": 100,
#           "score": {
#             "value": 0.11257359,
#             "type": "PROBABILITY"
#           }
#         }
#       ],
#       "summaryScore": {
#         "value": 0.11257359,
#         "type": "PROBABILITY"
#       }
#     }
#   },
#   "languages": [
#     "pt"
#   ],
#   "detectedLanguages": [
#     "pt"
#   ]
# }
# jairbolsonaro compra as vacinas bolsonaroncadê as vacinas bolsonarononde está as vacinas bolsonaronvacine a população bolsonaronsão mais de mil mortos por dia sem vacinas bolsonaronvacina vacina vacina vacina e nqueremos vacinas bolsonaronninguém aguenta esperar as vacinas bolsonaro
# {
#   "attributeScores": {
#     "TOXICITY": {
#       "spanScores": [
#         {
#           "begin": 0,
#           "end": 100,
#           "score": {
#             "value": 0.11257359,
#             "type": "PROBABILITY"
#           }
#         }
#       ],
#       "summaryScore": {
#         "value": 0.11257359,
#         "type": "PROBABILITY"
#       }
#     }
#   },
#   "languages": [
#     "pt"
#   ],
#   "detectedLanguages": [
#     "pt"
#   ]
# }
# presidente do senado diz esperar que ministério demonstre com ações que não é negacionista  política
# {
#   "attributeScores": {
#     "TOXICITY": {
#       "spanScores": [
#         {
#           "begin": 0,
#           "end": 100,
#           "score": {
#             "value": 0.11257359,
#             "type": "PROBABILITY"
#           }
#         }
#       ],
#       "summaryScore": {
#         "value": 0.11257359,
#         "type": "PROBABILITY"
#       }
#     }
#   },
#   "languages": [
#     "pt"
#   ],
#   "detectedLanguages": [
#     "pt"
#   ]
# }
# a hipocrisia do poder público no combate à  é o retrato falado de um governo de merda
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-74f0b050ec20> in <module>
#      17     analyze_request.get(line)
#      18     print(line)
# ---> 19     time.sleep(2)
#      20
#      21     response = client.comments().analyze(body=analyze_request).execute()
#
# KeyboardInterrupt:

# %% [markdown]
# # Parte 3 - Análise da resposta do Perspective API
